# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ## Data Cleaning
#
# ### Brief Summary:
# Due to the pre-cleaned nature of the data, the dataset utilized for this analysis consists of no duplicate observations as well as no missing values. Thus, the cleaning process only consists of selecting relevant rows and columns to conduct time series forecasting using both univariate and multivariate datasets.

# %% [markdown]
# ### Remove Irrelevant Columns

# %%
#Load the data
data=pd.read_csv(r"C:\Users\hajar\Time-Series-Crime-Forecasting-Minneapolis-3\data\Crime_Data.csv")

#Remove irrelevant columns
cols_to_be_deleted = [
    "Case_Number", "Case_NumberAlt", "Occurred_Date",
    "NIBRS_Code","Problem_Initial", "Problem_Final","Address",
    "wgsXAnon","wgsYAnon", "X","Y","OBJECTID","Offense","NIBRS_Group",
    "Latitude","Longitude", "Neighborhood", "Precinct"
]

data=data.drop(columns=cols_to_be_deleted)
data
# Out:
#                             Type           Reported_Date NIBRS_Crime_Against  \
# 0       Additional Crime Metrics  2019/01/05 02:50:00+00      Non NIBRS Data
# 1       Additional Crime Metrics  2019/01/08 12:22:00+00      Non NIBRS Data
# 2       Additional Crime Metrics  2019/01/10 14:10:00+00      Non NIBRS Data
# 3       Additional Crime Metrics  2019/01/27 06:52:00+00      Non NIBRS Data
# 4       Additional Crime Metrics  2019/02/03 03:24:00+00      Non NIBRS Data
# ...                          ...                     ...                 ...
# 323390         Shots Fired Calls  2025/03/07 00:20:43+00      Non NIBRS Data
# 323391         Shots Fired Calls  2025/03/07 14:24:33+00      Non NIBRS Data
# 323392         Shots Fired Calls  2025/03/08 00:12:37+00      Non NIBRS Data
# 323393         Shots Fired Calls  2025/03/09 19:44:43+00      Non NIBRS Data
# 323394         Shots Fired Calls  2025/03/10 20:28:58+00      Non NIBRS Data
#
#                         Offense_Category  Ward  Crime_Count
# 0       Subset of NIBRS Assault Offenses   6.0            1
# 1       Subset of NIBRS Assault Offenses   4.0            1
# 2       Subset of NIBRS Assault Offenses   5.0            1
# 3       Subset of NIBRS Assault Offenses   4.0            1
# 4       Subset of NIBRS Assault Offenses   1.0            1
# ...                                  ...   ...          ...
# 323390                 Shots Fired Calls   5.0            1
# 323391                 Shots Fired Calls   4.0            1
# 323392                 Shots Fired Calls   2.0            1
# 323393                 Shots Fired Calls   4.0            1
# 323394                 Shots Fired Calls   4.0            1
#
# [323395 rows x 6 columns]

# %% [markdown]
# ### Remove Irrelevant Rows

# %%
data = data[data.Type =="Crime Offenses (NIBRS)"]
data = data[data.NIBRS_Crime_Against != "Not a Crime "]
data=data.drop(columns=['Type']) #Now all the observations are Crime Offenses

data
# Out:
#                  Reported_Date NIBRS_Crime_Against  \
# 15      2019/01/01 07:53:00+00             Person
# 16      2019/01/04 10:07:00+00           Property
# 17      2019/01/01 03:23:00+00           Property
# 33      2019/01/02 04:04:00+00           Property
# 34      2019/01/04 05:27:00+00           Property
# ...                        ...                 ...
# 318591  2025/03/06 21:19:00+00           Property
# 318592  2025/03/07 13:04:00+00           Property
# 318593  2025/03/08 11:57:00+00           Property
# 318594  2025/03/10 11:44:00+00           Property
# 318595  2025/03/09 20:42:00+00           Property
#
#                                  Offense_Category  Ward  Crime_Count
# 15                              Assault Offenses   10.0            1
# 16      Destruction/Damage/Vandalism of Property    3.0            1
# 17      Destruction/Damage/Vandalism of Property    1.0            1
# 33                        Larceny/Theft Offenses    1.0            1
# 34                      Stolen Property Offenses    4.0            1
# ...                                           ...   ...          ...
# 318591                    Larceny/Theft Offenses   10.0            1
# 318592                    Larceny/Theft Offenses   12.0            1
# 318593  Destruction/Damage/Vandalism of Property    8.0            1
# 318594                    Larceny/Theft Offenses    8.0            1
# 318595                    Larceny/Theft Offenses    3.0            1
#
# [266185 rows x 5 columns]

# %% [markdown]
# ### Remove Duplicates and Expand Data

# %%
print ("Rows     : " ,data.shape[0])
print ("Columns  : " ,data.shape[1])
print ("\nFeatures : \n\n" ,data.columns.tolist())
print ("\nMissing values : \n\n", data.isnull().any())
print ("\nUnique values :  \n\n",data.nunique())
# Out:
# Rows     :  266185
# Columns  :  5
#
# Features :
#
#  ['Reported_Date', 'NIBRS_Crime_Against', 'Offense_Category', 'Ward', 'Crime_Count']
#
# Missing values :
#
#  Reported_Date          False
# NIBRS_Crime_Against    False
# Offense_Category       False
# Ward                    True
# Crime_Count            False
# dtype: bool
#
# Unique values :
#
#  Reported_Date          234248
# NIBRS_Crime_Against         3
# Offense_Category           23
# Ward                       13
# Crime_Count                15
# dtype: int64

# %%
category_counts = data['Crime_Count'].value_counts()
category_counts
# Out:
# Crime_Count
# 1     259930
# 2       4857
# 3        854
# 4        313
# 5        122
# 6         40
# 7         32
# 8         13
# 9          8
# 10         5
# 12         4
# 11         3
# 14         2
# 13         1
# 21         1
# Name: count, dtype: int64

# %% [markdown]
# ### Convert Reported_Date to datetime type and make a Date Time Column

# %%
# change the column date dtype from object to date
data.Reported_Date= pd.to_datetime(data.Reported_Date, format='%Y/%m/%d %H:%M:%S%z')
data['Date']= data['Reported_Date'].dt.date
data['Time']= data['Reported_Date'].dt.time
data['Month']= data['Reported_Date'].dt.month
data['Year']= data['Reported_Date'].dt.year

# setting the index to be the date 
data.index = pd.DatetimeIndex(data.Reported_Date)
data=data.drop(columns=['Reported_Date'])
data
# Out:
#                           NIBRS_Crime_Against  \
# Reported_Date
# 2019-01-01 07:53:00+00:00             Person
# 2019-01-04 10:07:00+00:00           Property
# 2019-01-01 03:23:00+00:00           Property
# 2019-01-02 04:04:00+00:00           Property
# 2019-01-04 05:27:00+00:00           Property
# ...                                       ...
# 2025-03-06 21:19:00+00:00           Property
# 2025-03-07 13:04:00+00:00           Property
# 2025-03-08 11:57:00+00:00           Property
# 2025-03-10 11:44:00+00:00           Property
# 2025-03-09 20:42:00+00:00           Property
#
#                                                     Offense_Category  Ward  \
# Reported_Date
# 2019-01-01 07:53:00+00:00                          Assault Offenses   10.0
# 2019-01-04 10:07:00+00:00  Destruction/Damage/Vandalism of Property    3.0
# 2019-01-01 03:23:00+00:00  Destruction/Damage/Vandalism of Property    1.0
# 2019-01-02 04:04:00+00:00                    Larceny/Theft Offenses    1.0
# 2019-01-04 05:27:00+00:00                  Stolen Property Offenses    4.0
# ...                                                              ...   ...
# 2025-03-06 21:19:00+00:00                    Larceny/Theft Offenses   10.0
# 2025-03-07 13:04:00+00:00                    Larceny/Theft Offenses   12.0
# 2025-03-08 11:57:00+00:00  Destruction/Damage/Vandalism of Property    8.0
# 2025-03-10 11:44:00+00:00                    Larceny/Theft Offenses    8.0
# 2025-03-09 20:42:00+00:00                    Larceny/Theft Offenses    3.0
#
#                            Crime_Count        Date      Time  Month  Year
# Reported_Date
# 2019-01-01 07:53:00+00:00            1  2019-01-01  07:53:00      1  2019
# 2019-01-04 10:07:00+00:00            1  2019-01-04  10:07:00      1  2019
# 2019-01-01 03:23:00+00:00            1  2019-01-01  03:23:00      1  2019
# 2019-01-02 04:04:00+00:00            1  2019-01-02  04:04:00      1  2019
# 2019-01-04 05:27:00+00:00            1  2019-01-04  05:27:00      1  2019
# ...                                ...         ...       ...    ...   ...
# 2025-03-06 21:19:00+00:00            1  2025-03-06  21:19:00      3  2025
# 2025-03-07 13:04:00+00:00            1  2025-03-07  13:04:00      3  2025
# 2025-03-08 11:57:00+00:00            1  2025-03-08  11:57:00      3  2025
# 2025-03-10 11:44:00+00:00            1  2025-03-10  11:44:00      3  2025
# 2025-03-09 20:42:00+00:00            1  2025-03-09  20:42:00      3  2025
#
# [266185 rows x 8 columns]

# %% [markdown]
# ### Examine the number of missing values

# %%
# Examine the percent of missing data from each column
data.isnull().sum().sort_values(ascending=False)/len(data)*100
# Out:
# Ward                   0.785544
# NIBRS_Crime_Against    0.000000
# Offense_Category       0.000000
# Crime_Count            0.000000
# Date                   0.000000
# Time                   0.000000
# Month                  0.000000
# Year                   0.000000
# dtype: float64

# %%
# Remove missing Data
print(data.size)
data = data.dropna()
print(data.size)
# Out:
# 2129480
# 2112752

# %% [markdown]
# ### Step 6: Create a new CSV files for the Cleaned Dataset

# %%
#Reorder data
data = data.loc[:, ['Date','Year','Month', 'Time', 'Offense_Category','NIBRS_Crime_Against', 'Ward','Crime_Count']]

#create csv
data.to_csv(r"C:\Users\hajar\Time-Series-Crime-Forecasting-Minneapolis-3\data\Clean_Data.csv", index=False)
data
# Out:
#                                  Date  Year  Month      Time  \
# Reported_Date
# 2019-01-01 07:53:00+00:00  2019-01-01  2019      1  07:53:00
# 2019-01-04 10:07:00+00:00  2019-01-04  2019      1  10:07:00
# 2019-01-01 03:23:00+00:00  2019-01-01  2019      1  03:23:00
# 2019-01-02 04:04:00+00:00  2019-01-02  2019      1  04:04:00
# 2019-01-04 05:27:00+00:00  2019-01-04  2019      1  05:27:00
# ...                               ...   ...    ...       ...
# 2025-03-06 21:19:00+00:00  2025-03-06  2025      3  21:19:00
# 2025-03-07 13:04:00+00:00  2025-03-07  2025      3  13:04:00
# 2025-03-08 11:57:00+00:00  2025-03-08  2025      3  11:57:00
# 2025-03-10 11:44:00+00:00  2025-03-10  2025      3  11:44:00
# 2025-03-09 20:42:00+00:00  2025-03-09  2025      3  20:42:00
#
#                                                     Offense_Category  \
# Reported_Date
# 2019-01-01 07:53:00+00:00                          Assault Offenses
# 2019-01-04 10:07:00+00:00  Destruction/Damage/Vandalism of Property
# 2019-01-01 03:23:00+00:00  Destruction/Damage/Vandalism of Property
# 2019-01-02 04:04:00+00:00                    Larceny/Theft Offenses
# 2019-01-04 05:27:00+00:00                  Stolen Property Offenses
# ...                                                              ...
# 2025-03-06 21:19:00+00:00                    Larceny/Theft Offenses
# 2025-03-07 13:04:00+00:00                    Larceny/Theft Offenses
# 2025-03-08 11:57:00+00:00  Destruction/Damage/Vandalism of Property
# 2025-03-10 11:44:00+00:00                    Larceny/Theft Offenses
# 2025-03-09 20:42:00+00:00                    Larceny/Theft Offenses
#
#                           NIBRS_Crime_Against  Ward  Crime_Count
# Reported_Date
# 2019-01-01 07:53:00+00:00             Person   10.0            1
# 2019-01-04 10:07:00+00:00           Property    3.0            1
# 2019-01-01 03:23:00+00:00           Property    1.0            1
# 2019-01-02 04:04:00+00:00           Property    1.0            1
# 2019-01-04 05:27:00+00:00           Property    4.0            1
# ...                                       ...   ...          ...
# 2025-03-06 21:19:00+00:00           Property   10.0            1
# 2025-03-07 13:04:00+00:00           Property   12.0            1
# 2025-03-08 11:57:00+00:00           Property    8.0            1
# 2025-03-10 11:44:00+00:00           Property    8.0            1
# 2025-03-09 20:42:00+00:00           Property    3.0            1
#
# [264094 rows x 8 columns]

# %% [markdown]
# ### Step 8: Create a Univariate dataset with just Date and Occurences

# %%
#univariate dataset for date
Univ_Crime=data.drop(columns=['NIBRS_Crime_Against','Offense_Category','Time','Ward'])
Univ_Crime=Univ_Crime.groupby('Date')['Crime_Count'].sum()

#change series to dataframe
Univ_Crime=Univ_Crime.to_frame()

# %%
#create csv
Univ_Crime.to_csv(r"C:\Users\hajar\Time-Series-Crime-Forecasting-Minneapolis-3\data\Univ_Date.csv")
Univ_Crime
# Out:
#             Crime_Count
# Date
# 2019-01-01           88
# 2019-01-02          102
# 2019-01-03          133
# 2019-01-04           95
# 2019-01-05           83
# ...                 ...
# 2025-03-06           89
# 2025-03-07           89
# 2025-03-08           70
# 2025-03-09           80
# 2025-03-10           50
#
# [2261 rows x 1 columns]

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ## Data Cleaning
#
# ### Brief Summary:
# Due to the pre-cleaned nature of the data, the dataset utilized for this analysis consists of no duplicate observations as well as no missing values. Thus, the cleaning process only consists of selecting relevant rows and columns to conduct time series forecasting using both univariate and multivariate datasets.

# %% [markdown]
# ### Step 1: Load the Data and remove irrelevant columns

# %%
#Load the data
data=pd.read_csv(r"C:\Users\hajar\Time-Series-Crime-Forecasting-Minneapolis-3\data\Crime_Data.csv")

#Remove irrelevant columns
cols_to_be_deleted = [
    "Case_Number", "Case_NumberAlt", "Occurred_Date",
    "NIBRS_Code","Problem_Initial", "Problem_Final","Address",
    "wgsXAnon","wgsYAnon", "X","Y","OBJECTID","Offense","NIBRS_Group"
]

data=data.drop(columns=cols_to_be_deleted)
data
# Out:
#                             Type           Reported_Date NIBRS_Crime_Against  \
# 0       Additional Crime Metrics  2019/01/05 02:50:00+00      Non NIBRS Data
# 1       Additional Crime Metrics  2019/01/08 12:22:00+00      Non NIBRS Data
# 2       Additional Crime Metrics  2019/01/10 14:10:00+00      Non NIBRS Data
# 3       Additional Crime Metrics  2019/01/27 06:52:00+00      Non NIBRS Data
# 4       Additional Crime Metrics  2019/02/03 03:24:00+00      Non NIBRS Data
# ...                          ...                     ...                 ...
# 323390         Shots Fired Calls  2025/03/07 00:20:43+00      Non NIBRS Data
# 323391         Shots Fired Calls  2025/03/07 14:24:33+00      Non NIBRS Data
# 323392         Shots Fired Calls  2025/03/08 00:12:37+00      Non NIBRS Data
# 323393         Shots Fired Calls  2025/03/09 19:44:43+00      Non NIBRS Data
# 323394         Shots Fired Calls  2025/03/10 20:28:58+00      Non NIBRS Data
#
#                         Offense_Category  Precinct       Neighborhood  Ward  \
# 0       Subset of NIBRS Assault Offenses       1.0        Elliot Park   6.0
# 1       Subset of NIBRS Assault Offenses       4.0          Cleveland   4.0
# 2       Subset of NIBRS Assault Offenses       4.0      Willard - Hay   5.0
# 3       Subset of NIBRS Assault Offenses       4.0    Webber - Camden   4.0
# 4       Subset of NIBRS Assault Offenses       2.0            Holland   1.0
# ...                                  ...       ...                ...   ...
# 323390                 Shots Fired Calls       4.0      Willard - Hay   5.0
# 323391                 Shots Fired Calls       4.0     Lind - Bohanon   4.0
# 323392                 Shots Fired Calls       3.0             Seward   2.0
# 323393                 Shots Fired Calls       4.0            Folwell   4.0
# 323394                 Shots Fired Calls       4.0  Camden Industrial   4.0
#
#         Latitude  Longitude  Crime_Count
# 0       44.96717  -93.26638            1
# 1       45.01595  -93.31080            1
# 2       44.99875  -93.30506            1
# 3       45.03545  -93.30123            1
# 4       45.01089  -93.24469            1
# ...          ...        ...          ...
# 323390  44.99687  -93.30444            1
# 323391  45.04843  -93.29278            1
# 323392  44.95918  -93.22761            1
# 323393  44.97179  -93.26176            1
# 323394  45.03546  -93.28810            1
#
# [323395 rows x 10 columns]

# %% [markdown]
# ### Step 2: Remove all rows that don't pretain to Crime Offenses (NIBRS) or are labled "Not a Crime"

# %%
data = data[data.Type =="Crime Offenses (NIBRS)"]
data = data[data.NIBRS_Crime_Against != "Not a Crime "]
#data.NIBRS_Crime_Against.value_counts()
data
# Out:
#                           Type           Reported_Date NIBRS_Crime_Against  \
# 15      Crime Offenses (NIBRS)  2019/01/01 07:53:00+00             Person
# 16      Crime Offenses (NIBRS)  2019/01/04 10:07:00+00           Property
# 17      Crime Offenses (NIBRS)  2019/01/01 03:23:00+00           Property
# 33      Crime Offenses (NIBRS)  2019/01/02 04:04:00+00           Property
# 34      Crime Offenses (NIBRS)  2019/01/04 05:27:00+00           Property
# ...                        ...                     ...                 ...
# 318591  Crime Offenses (NIBRS)  2025/03/06 21:19:00+00           Property
# 318592  Crime Offenses (NIBRS)  2025/03/07 13:04:00+00           Property
# 318593  Crime Offenses (NIBRS)  2025/03/08 11:57:00+00           Property
# 318594  Crime Offenses (NIBRS)  2025/03/10 11:44:00+00           Property
# 318595  Crime Offenses (NIBRS)  2025/03/09 20:42:00+00           Property
#
#                                  Offense_Category  Precinct  \
# 15                              Assault Offenses        5.0
# 16      Destruction/Damage/Vandalism of Property        1.0
# 17      Destruction/Damage/Vandalism of Property        2.0
# 33                        Larceny/Theft Offenses        2.0
# 34                      Stolen Property Offenses        4.0
# ...                                           ...       ...
# 318591                    Larceny/Theft Offenses        5.0
# 318592                    Larceny/Theft Offenses        3.0
# 318593  Destruction/Damage/Vandalism of Property        5.0
# 318594                    Larceny/Theft Offenses        3.0
# 318595                    Larceny/Theft Offenses        2.0
#
#              Neighborhood  Ward  Latitude  Longitude  Crime_Count
# 15        Lowry Hill East  10.0  44.95643  -93.29186            1
# 16             North Loop   3.0  44.98658  -93.27071            1
# 17       Marshall Terrace   1.0  45.01407  -93.26314            1
# 33                   Como   1.0  44.98879  -93.22155            1
# 34        Webber - Camden   4.0  45.02756  -93.28540            1
# ...                   ...   ...       ...        ...          ...
# 318591  East Bde Maka Ska  10.0  44.93952  -93.30155            1
# 318592           Hiawatha  12.0  44.91445  -93.21708            1
# 318593            Lyndale   8.0  44.94293  -93.28051            1
# 318594             Regina   8.0  44.92152  -93.26829            1
# 318595           Sheridan   3.0  45.00254  -93.27116            1
#
# [266185 rows x 10 columns]

# %% [markdown]
# ### Step 3: Create a seperate Column for Time

# %%
#create two new columns for date and time
data[['Date','Time']]= data.Reported_Date.str.split(expand=True)

#remove type (since they all have the same type) and crime count since each observation has a crime count of 1
data= data.drop(columns=["Type","Crime_Count","Reported_Date"])
data
# Out:
#        NIBRS_Crime_Against                           Offense_Category  \
# 15                 Person                           Assault Offenses
# 16               Property   Destruction/Damage/Vandalism of Property
# 17               Property   Destruction/Damage/Vandalism of Property
# 33               Property                     Larceny/Theft Offenses
# 34               Property                   Stolen Property Offenses
# ...                    ...                                        ...
# 318591           Property                     Larceny/Theft Offenses
# 318592           Property                     Larceny/Theft Offenses
# 318593           Property   Destruction/Damage/Vandalism of Property
# 318594           Property                     Larceny/Theft Offenses
# 318595           Property                     Larceny/Theft Offenses
#
#         Precinct       Neighborhood  Ward  Latitude  Longitude        Date  \
# 15           5.0    Lowry Hill East  10.0  44.95643  -93.29186  2019/01/01
# 16           1.0         North Loop   3.0  44.98658  -93.27071  2019/01/04
# 17           2.0   Marshall Terrace   1.0  45.01407  -93.26314  2019/01/01
# 33           2.0               Como   1.0  44.98879  -93.22155  2019/01/02
# 34           4.0    Webber - Camden   4.0  45.02756  -93.28540  2019/01/04
# ...          ...                ...   ...       ...        ...         ...
# 318591       5.0  East Bde Maka Ska  10.0  44.93952  -93.30155  2025/03/06
# 318592       3.0           Hiawatha  12.0  44.91445  -93.21708  2025/03/07
# 318593       5.0            Lyndale   8.0  44.94293  -93.28051  2025/03/08
# 318594       3.0             Regina   8.0  44.92152  -93.26829  2025/03/10
# 318595       2.0           Sheridan   3.0  45.00254  -93.27116  2025/03/09
#
#                Time
# 15      07:53:00+00
# 16      10:07:00+00
# 17      03:23:00+00
# 33      04:04:00+00
# 34      05:27:00+00
# ...             ...
# 318591  21:19:00+00
# 318592  13:04:00+00
# 318593  11:57:00+00
# 318594  11:44:00+00
# 318595  20:42:00+00
#
# [266185 rows x 9 columns]

# %% [markdown]
# ### Step 5: create two cleaned data sets (univariate and multivariate)

# %%
univar_dat=data.drop(columns=["Time","Longitude","Latitude", "Ward", "Neighborhood","Precinct", "Offense_Category","NIBRS_Crime_Against"])
multvar_dat=data

# %% [markdown]
# ### Step 6: Create two new CSV files for the cleaned datasets

# %%
#fix univariate data

#create column with each date
#create another column with counts of crimes for each date
#univar_dat['Crimes']= data.Date.value_counts()
#univar_dat.Date.drop_duplicates()
#univar_dat

univar_dat.to_csv(r"C:\Users\hajar\Time-Series-Crime-Forecasting-Minneapolis-3\data\Univ_Data.csv", index=False)
multvar_dat.to_csv(r"C:\Users\hajar\Time-Series-Crime-Forecasting-Minneapolis-3\data\Multiv_Data.csv", index=False)
# Out:
#               Date  Crimes
# 15      2019/01/01     NaN
# 16      2019/01/04     NaN
# 17      2019/01/01     NaN
# 33      2019/01/02     NaN
# 34      2019/01/04     NaN
# ...            ...     ...
# 318591  2025/03/06     NaN
# 318592  2025/03/07     NaN
# 318593  2025/03/08     NaN
# 318594  2025/03/10     NaN
# 318595  2025/03/09     NaN
#
# [266185 rows x 2 columns]

# %% [markdown]
# ### Step 7: Visualize the first couple rows of the cleaned data

# %%
multvar_dat
# Out:
#                  Reported_Date NIBRS_Crime_Against  \
# 15      2019/01/01 07:53:00+00             Person
# 16      2019/01/04 10:07:00+00           Property
# 17      2019/01/01 03:23:00+00           Property
# 33      2019/01/02 04:04:00+00           Property
# 34      2019/01/04 05:27:00+00           Property
# ...                        ...                 ...
# 318591  2025/03/06 21:19:00+00           Property
# 318592  2025/03/07 13:04:00+00           Property
# 318593  2025/03/08 11:57:00+00           Property
# 318594  2025/03/10 11:44:00+00           Property
# 318595  2025/03/09 20:42:00+00           Property
#
#                                  Offense_Category  Precinct  \
# 15                              Assault Offenses        5.0
# 16      Destruction/Damage/Vandalism of Property        1.0
# 17      Destruction/Damage/Vandalism of Property        2.0
# 33                        Larceny/Theft Offenses        2.0
# 34                      Stolen Property Offenses        4.0
# ...                                           ...       ...
# 318591                    Larceny/Theft Offenses        5.0
# 318592                    Larceny/Theft Offenses        3.0
# 318593  Destruction/Damage/Vandalism of Property        5.0
# 318594                    Larceny/Theft Offenses        3.0
# 318595                    Larceny/Theft Offenses        2.0
#
#              Neighborhood  Ward  Latitude  Longitude        Date         Time
# 15        Lowry Hill East  10.0  44.95643  -93.29186  2019/01/01  07:53:00+00
# 16             North Loop   3.0  44.98658  -93.27071  2019/01/04  10:07:00+00
# 17       Marshall Terrace   1.0  45.01407  -93.26314  2019/01/01  03:23:00+00
# 33                   Como   1.0  44.98879  -93.22155  2019/01/02  04:04:00+00
# 34        Webber - Camden   4.0  45.02756  -93.28540  2019/01/04  05:27:00+00
# ...                   ...   ...       ...        ...         ...          ...
# 318591  East Bde Maka Ska  10.0  44.93952  -93.30155  2025/03/06  21:19:00+00
# 318592           Hiawatha  12.0  44.91445  -93.21708  2025/03/07  13:04:00+00
# 318593            Lyndale   8.0  44.94293  -93.28051  2025/03/08  11:57:00+00
# 318594             Regina   8.0  44.92152  -93.26829  2025/03/10  11:44:00+00
# 318595           Sheridan   3.0  45.00254  -93.27116  2025/03/09  20:42:00+00
#
# [266185 rows x 10 columns]
